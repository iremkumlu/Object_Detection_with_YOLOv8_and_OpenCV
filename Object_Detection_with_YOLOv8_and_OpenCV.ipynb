# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os

# %%
colab_path = "/content/drive/MyDrive/yolov8"
os.chdir(colab_path)

# %%
# !pwd
# Out:
# /content/drive/MyDrive/yolov8

# %%
# !ls

# %%
from IPython.display import Image

# %%
# !pip install ultralytics

# %%
import torch

# %% [markdown]
# ekran kartına bağlı mı bakalım

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.__version__
# Out:
# '2.5.1+cu121'

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.33 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.5/112.6 GB disk)

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/drive/MyDrive/yolov8/image1.jpg"
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 87.9MB/s]
# Ultralytics 8.3.33 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/yolov8/image1.jpg: 544x640 5 persons, 1 bus, 1 train, 1 handbag, 63.3ms
# Speed: 12.7ms preprocess, 63.3ms inference, 1111.8ms postprocess per image at shape (1, 3, 544, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image("/content/drive/MyDrive/yolov8/runs/detect/predict/image1.jpg")

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="https://ultralytics.com/images/zidane.jpg"
# Out:
# Ultralytics 8.3.33 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 49.2k/49.2k [00:00<00:00, 20.8MB/s]
# image 1/1 /content/drive/MyDrive/yolov8/zidane.jpg: 384x640 2 persons, 1 tie, 55.7ms
# Speed: 2.9ms preprocess, 55.7ms inference, 630.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image("/content/drive/MyDrive/yolov8/runs/detect/predict2/zidane.jpg")

# %% [markdown]
# Koordinatları bulalım.

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="https://ultralytics.com/images/zidane.jpg" save_txt=True
# Out:
# Ultralytics 8.3.33 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://ultralytics.com/images/zidane.jpg locally at zidane.jpg
# image 1/1 /content/drive/MyDrive/yolov8/zidane.jpg: 384x640 2 persons, 1 tie, 64.0ms
# Speed: 3.6ms preprocess, 64.0ms inference, 886.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict3
# 1 label saved to runs/detect/predict3/labels
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# Etiketleri ve conf değerlerini saklayalım.

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/drive/MyDrive/yolov8/image1.jpg" hide_labels=True hide_conf=True
# Out:
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in in the future. Use 'show_labels' instead.
# WARNING ⚠️ 'hide_conf' is deprecated and will be removed in in the future. Use 'show_conf' instead.
# Ultralytics 8.3.33 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/yolov8/image1.jpg: 544x640 5 persons, 1 bus, 1 train, 1 handbag, 39.5ms
# Speed: 3.2ms preprocess, 39.5ms inference, 615.4ms postprocess per image at shape (1, 3, 544, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# resmin içindeki nesneleri ayıralım.

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/drive/MyDrive/yolov8/image1.jpg" save_crop=True
# Out:
# Ultralytics 8.3.33 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/yolov8/image1.jpg: 544x640 5 persons, 1 bus, 1 train, 1 handbag, 38.5ms
# Speed: 3.2ms preprocess, 38.5ms inference, 685.2ms postprocess per image at shape (1, 3, 544, 640)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# opencv ile detect işlemi yapalım.

# %%
import cv2
from google.colab.patches import cv2_imshow
import imutils

img=cv2.imread("/content/drive/MyDrive/yolov8/runs/detect/predict2/zidane.jpg")
img=imutils.resize(img, width=480)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=480x270>

# %%
import cv2
from google.colab.patches import cv2_imshow
import imutils

from ultralytics import YOLO
font=cv2.FONT_HERSHEY_TRIPLEX

img_path="image1.jpg"
model_path="yolov8n.pt"

model=YOLO(model_path)
img=cv2.imread(img_path)
img=imutils.resize(img,width=480)

results=model(img)[0]

threshold=0.5

for result in results.boxes.data.tolist():
  x1,y1,x2,y2,score,class_id=result
  x1,y1,x2,y2,class_id=int(x1),int(y1),int(x2),int(y2),int(class_id)

  if score>threshold:
    cv2.rectangle(img,(x1,y1),(x2,y2),(0,0,255),2)

    class_name=results.names[class_id]
    score=score*100

    text=f"{class_name}:%{score:.2f}"

    cv2.putText(img,text,(x1,y1-10),font,0.5,(0,0,255),1,cv2.LINE_AA)

cv2_imshow(img)
# Out:
# 0: 544x640 6 persons, 1 bus, 1 train, 1 handbag, 1 suitcase, 12.0ms
# Speed: 5.8ms preprocess, 12.0ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
# <PIL.Image.Image image mode=RGB size=480x402>
